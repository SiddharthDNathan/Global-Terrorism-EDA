# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddharthDNathan/Global-Terrorism-EDA/blob/main/Global_Terrorism_EDA_Submission_according_to_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Global Terrorism EDA

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# Summary:
#
# The Global Terrorism Database™ (GTD), maintained by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) at the University of Maryland, serves as a comprehensive repository of terrorism-related events worldwide since 1970. With over 200,000 meticulously documented records, the GTD provides invaluable insights into the patterns, causes, and consequences of terrorist activities, facilitating research, analysis, and informed decision-making for various stakeholders.
#
# The methodology employed in compiling the GTD is rooted in transparency and rigor. The database follows a systematic data collection approach, adhering to predefined inclusion criteria and robust definitional filtering mechanisms to ensure consistency and accuracy. Through periodic updates and revisions, the GTD continuously evolves to reflect the dynamic nature of terrorism, incorporating new data and methodologies to enhance its utility and relevance.
#
# The GTD encompasses a diverse range of variables, organized into categories such as incident details, attack methods, target demographics, perpetrator characteristics, casualty information, and more. Each variable is meticulously defined, allowing users to conduct nuanced analyses and derive meaningful insights into the multifaceted nature of terrorism worldwide.
#
# Key features of the GTD include its public availability for search, browsing, and download on the GTD website, along with a commercial distribution partnership established in 2019 with CHC Global. However, access to the database is subject to the terms of the End User License Agreement, ensuring responsible use and adherence to ethical guidelines in handling sensitive information related to terrorism.
#
# For researchers, policymakers, and practitioners alike, the GTD serves as a powerful tool for understanding terrorism dynamics, identifying emerging trends and hotspots, evaluating the effectiveness of counterterrorism measures, and informing evidence-based strategies to mitigate the impact of terrorism on societies and communities worldwide.
#
# In conclusion, the GTD stands as a testament to the collaborative efforts of academia, government agencies, and research institutions in addressing one of the most pressing challenges of our time. By providing a comprehensive and reliable source of terrorism data, the GTD empowers stakeholders to advance knowledge, foster dialogue, and ultimately contribute to a safer and more secure world.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/SiddharthDNathan/Global-Terrorism-EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **To explore and analyze the data to discover the statistics of various incidents of Global Terrorism**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **To gather insights to help in decision making for prevention of such future incidents**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('/content/drive/MyDrive/TerrorismData.csv', encoding = 'iso-8859-1')
# Out:
# <ipython-input-3-ca5b10e021bb>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/TerrorismData.csv', encoding = 'iso-8859-1')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Global Terrorism Database™ (GTD), maintained by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) at the University of Maryland, is an event-level database documenting over 200,000 terrorist incidents worldwide since 1970. This codebook, which is updated periodically, outlines the GTD's data collection methodology, inclusion criteria, and detailed variable definitions, aiming for transparency and consistency in documenting terrorist attacks. It encompasses various data points such as incident details, attack methods, target information, perpetrator data, and consequences, among others. The GTD is available for public use on its website, with commercial distribution managed by CHC Global since 2019, subject to an End User License Agreement. The GTD team encourages feedback and inquiries via their email to enhance the utility and accuracy of the database for users interested in analyzing terrorism trends and impacts.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Dataset Describe
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
for col in df.columns:
  print(col, len(df[col].unique()))
# Out:
# eventid 181691
# iyear 47
# imonth 13
# iday 32
# approxdate 2245
# extended 2
# resolution 1860
# country 205
# country_txt 205
# region 12
# region_txt 12
# provstate 2856
# city 36675
# latitude 48323
# longitude 48040
# specificity 6
# vicinity 3
# location 44110
# summary 112493
# crit1 2
# crit2 2
# crit3 2
# doubtterr 4
# alternative 6
# alternative_txt 6
# multiple 3
# success 2
# suicide 2
# attacktype1 9
# attacktype1_txt 9
# attacktype2 10
# attacktype2_txt 10
# attacktype3 9
# attacktype3_txt 9
# targtype1 22
# targtype1_txt 22
# targsubtype1 113
# targsubtype1_txt 113
# corp1 33239
# target1 86007
# natlty1 216
# natlty1_txt 216
# targtype2 23
# targtype2_txt 23
# targsubtype2 108
# targsubtype2_txt 108
# corp2 2692
# target2 5044
# natlty2 159
# natlty2_txt 159
# targtype3 21
# targtype3_txt 21
# targsubtype3 93
# targsubtype3_txt 93
# corp3 423
# target3 721
# natlty3 111
# natlty3_txt 111
# gname 3537
# gsubname 1184
# gname2 434
# gsubname2 61
# gname3 117
# gsubname3 15
# motive 14491
# guncertain1 3
# guncertain2 3
# guncertain3 3
# individual 2
# nperps 114
# nperpcap 51
# claimed 4
# claimmode 11
# claimmode_txt 11
# claim2 4
# claimmode2 10
# claimmode2_txt 10
# claim3 3
# claimmode3 9
# claimmode3_txt 9
# compclaim 4
# weaptype1 12
# weaptype1_txt 12
# weapsubtype1 31
# weapsubtype1_txt 31
# weaptype2 12
# weaptype2_txt 12
# weapsubtype2 29
# weapsubtype2_txt 29
# weaptype3 11
# weaptype3_txt 11
# weapsubtype3 23
# weapsubtype3_txt 23
# weaptype4 6
# weaptype4_txt 6
# weapsubtype4 17
# weapsubtype4_txt 17
# weapdetail 19149
# nkill 206
# nkillus 32
# nkillter 97
# nwound 239
# nwoundus 45
# nwoundte 45
# property 3
# propextent 5
# propextent_txt 5
# propvalue 660
# propcomment 19158
# ishostkid 4
# nhostkid 210
# nhostkidus 28
# nhours 36
# ndays 329
# divert 144
# kidhijcountry 218
# ransom 4
# ransomamt 430
# ransomamtus 24
# ransompaid 157
# ransompaidus 9
# ransomnote 388
# hostkidoutcome 8
# hostkidoutcome_txt 8
# nreleased 157
# addnotes 15430
# scite1 83989
# scite2 62264
# scite3 36091
# dbsource 26
# INT_LOG 3
# INT_IDEO 3
# INT_MISC 3
# INT_ANY 3
# related 14307

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# The above df consists of 135 columns for unique categories of data which are not all usefull for further analysis, hence cleaning this data by generating a new df that consists of just the columns which are of use to us will be our step number 1 of DATA CLEANING ( we will use code book for this step).
# generating a base data for analysis from primary raw data, this new df consists of select columns from primary df which are actuall needed for further analysis and answer question and providing insights.
df = df.loc[:, ['eventid','iyear','imonth','iday','extended','country_txt','region_txt','city','latitude','longitude','vicinity','crit1','multiple','success','suicide','attacktype1_txt',
'targtype1_txt','natlty1_txt','gname','nperps','claimed','weaptype1_txt','nkill','nkillter','nwound','propextent_txt','ishostkid','ransom','nreleased']]

# %%
# Write your code to make your dataset analysis ready.
#renaming column for better understanding of data they contain.

df.rename(columns =
                  {'iyear':'year',
                   'imonth':'month',
                   'iday':'day',
                   'country_txt' : 'country',
                   'region_txt' : 'region',
                   'crit1' : 'crit',
                   'attacktype1_txt' : 'attacktype',
                   'targtype1_txt' : 'targettype',
                   'natlty1_txt' : 'nationalityofvic',
                   'gname' : 'organisation',
                   'claimed' : 'claimedresp',
                   'weaptype1_txt' : 'weapontype',
                   'nkill' : 'nkilled',
                   'nkillter' : 'nkillonlyter',
                   'nwound' : 'nwounded',
                   'propextent_txt' : 'propdamageextent',
                   'ishostkid' : 'victimkidnapped',
                   'ransom' : 'ransomdemanded',
                   }, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  int64
#  1   year              181691 non-null  int64
#  2   month             181691 non-null  int64
#  3   day               181691 non-null  int64
#  4   extended          181691 non-null  int64
#  5   country           181691 non-null  object
#  6   region            181691 non-null  object
#  7   city              181257 non-null  object
#  8   latitude          177135 non-null  float64
#  9   longitude         177134 non-null  float64
#  10  vicinity          181691 non-null  int64
#  11  crit              181691 non-null  int64
#  12  multiple          181690 non-null  float64
#  13  success           181691 non-null  int64
#  14  suicide           181691 non-null  int64
#  15  attacktype        181691 non-null  object
#  16  targettype        181691 non-null  object
#  17  nationalityofvic  180132 non-null  object
#  18  organisation      181691 non-null  object
#  19  nperps            110576 non-null  float64
#  20  claimedresp       115571 non-null  float64
#  21  weapontype        181691 non-null  object
#  22  nkilled           171378 non-null  float64
#  23  nkillonlyter      114733 non-null  float64
#  24  nwounded          165380 non-null  float64
#  25  propdamageextent  64065 non-null   object
#  26  victimkidnapped   181513 non-null  float64
#  27  ransomdemanded    77381 non-null   float64
#  28  nreleased         10400 non-null   float64
#  29  total_casualties  164817 non-null  float64
# dtypes: float64(12), int64(9), object(9)
# memory usage: 41.6+ MB

# %%
df.describe()
# Out:
#             eventid           year          month            day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended       latitude     longitude       vicinity  \
# count  181691.000000  177135.000000  1.771340e+05  181691.000000
# mean        0.045346      23.498343 -4.586957e+02       0.068297
# std         0.208063      18.569242  2.047790e+05       0.284553
# min         0.000000     -53.154613 -8.618590e+07      -9.000000
# 25%         0.000000      11.510046  4.545640e+00       0.000000
# 50%         0.000000      31.467463  4.324651e+01       0.000000
# 75%         0.000000      34.685087  6.871033e+01       0.000000
# max         1.000000      74.633553  1.793667e+02       1.000000
#
#                 crit       multiple  ...        suicide         nperps  \
# count  181691.000000  181690.000000  ...  181691.000000  110576.000000
# mean        0.988530       0.137773  ...       0.036507     -65.361154
# std         0.106483       0.344663  ...       0.187549     216.536633
# min         0.000000       0.000000  ...       0.000000     -99.000000
# 25%         1.000000       0.000000  ...       0.000000     -99.000000
# 50%         1.000000       0.000000  ...       0.000000     -99.000000
# 75%         1.000000       0.000000  ...       0.000000       1.000000
# max         1.000000       1.000000  ...       1.000000   25000.000000
#
#          claimedresp        nkilled   nkillonlyter       nwounded  \
# count  115571.000000  171378.000000  114733.000000  165380.000000
# mean        0.049666       2.403272       0.508058       3.167668
# std         1.093195      11.545741       4.199937      35.949392
# min        -9.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       2.000000       0.000000       2.000000
# max         1.000000    1570.000000     500.000000    8191.000000
#
#        victimkidnapped  ransomdemanded     nreleased  total_casualties
# count    181513.000000    77381.000000  10400.000000     164817.000000
# mean          0.059054       -0.145811    -29.018269          5.296128
# std           0.461244        1.207861     65.720119         42.069023
# min          -9.000000       -9.000000    -99.000000          0.000000
# 25%           0.000000        0.000000    -99.000000          0.000000
# 50%           0.000000        0.000000      0.000000          1.000000
# 75%           0.000000        0.000000      1.000000          4.000000
# max           1.000000        1.000000   2769.000000       9574.000000
#
# [8 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# eventid                  0
# year                     0
# month                    0
# day                      0
# extended                 0
# country                  0
# region                   0
# city                   434
# latitude              4556
# longitude             4557
# vicinity                 0
# crit                     0
# multiple                 1
# success                  0
# suicide                  0
# attacktype               0
# targettype               0
# nationalityofvic      1559
# organisation             0
# nperps               71115
# claimedresp          66120
# weapontype               0
# nkilled              10313
# nkillonlyter         66958
# nwounded             16311
# propdamageextent    117626
# victimkidnapped        178
# ransomdemanded      104310
# nreleased           171291
# total_casualties     16874
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The original dataframe consists of 135 columns for unique categories of data which are not all usefull for further analysis, hence cleaning this data by generating a new df that consists of just the columns which are of use to us was my step number 1 of DATA CLEANING ( we will use code book for this step)
#
# Furthermore the variable names were changed to improve readability.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
df #Final data frame for analysis and visualization
# Out:
#              eventid  year  month  day  extended             country  \
# 0       197000000001  1970      7    2         0  Dominican Republic
# 1       197000000002  1970      0    0         0              Mexico
# 2       197001000001  1970      1    0         0         Philippines
# 3       197001000002  1970      1    0         0              Greece
# 4       197001000003  1970      1    0         0               Japan
# ...              ...   ...    ...  ...       ...                 ...
# 181686  201712310022  2017     12   31         0             Somalia
# 181687  201712310029  2017     12   31         0               Syria
# 181688  201712310030  2017     12   31         0         Philippines
# 181689  201712310031  2017     12   31         0               India
# 181690  201712310032  2017     12   31         0         Philippines
#
#                              region           city   latitude   longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                     North America    Mexico city  19.371887  -99.086624
# 2                    Southeast Asia        Unknown  15.478598  120.599741
# 3                    Western Europe         Athens  37.997490   23.762728
# 4                         East Asia        Fukouka  33.580412  130.396361
# ...                             ...            ...        ...         ...
# 181686           Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687   Middle East & North Africa         Jableh  35.407278   35.942679
# 181688               Southeast Asia       Kubentog   6.900742  124.437908
# 181689                   South Asia         Imphal  24.798346   93.940430
# 181690               Southeast Asia  Cotabato City   7.209594  124.241966
#
#         ...  nperps  claimedresp  weapontype  nkilled  nkillonlyter nwounded  \
# 0       ...     NaN          NaN     Unknown      1.0           NaN      0.0
# 1       ...     7.0          NaN     Unknown      0.0           NaN      0.0
# 2       ...     NaN          NaN     Unknown      1.0           NaN      0.0
# 3       ...     NaN          NaN  Explosives      NaN           NaN      NaN
# 4       ...     NaN          NaN  Incendiary      NaN           NaN      NaN
# ...     ...     ...          ...         ...      ...           ...      ...
# 181686  ...   -99.0          1.0    Firearms      1.0           0.0      2.0
# 181687  ...   -99.0          0.0  Explosives      2.0           0.0      7.0
# 181688  ...   -99.0          0.0  Incendiary      0.0           0.0      0.0
# 181689  ...   -99.0          0.0  Explosives      0.0           0.0      0.0
# 181690  ...   -99.0          0.0  Explosives      0.0           0.0      0.0
#
#        propdamageextent victimkidnapped ransomdemanded  nreleased
# 0                   NaN             0.0            0.0        NaN
# 1                   NaN             1.0            1.0        NaN
# 2                   NaN             0.0            0.0        NaN
# 3                   NaN             0.0            0.0        NaN
# 4                   NaN             0.0            0.0        NaN
# ...                 ...             ...            ...        ...
# 181686              NaN             0.0            NaN        NaN
# 181687          Unknown             0.0            NaN        NaN
# 181688          Unknown             0.0            NaN        NaN
# 181689              NaN             0.0            NaN        NaN
# 181690              NaN             0.0            NaN        NaN
#
# [181691 rows x 29 columns]

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#Analysis of number of attacks per year
f = plt.figure(figsize=(20, 7))
xaxis = sns.countplot(x = 'year', data = df)
plt.ylabel('Count', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.title('Number of Terrorist Attack by Year', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Number of Terrorist Attack by Year')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get total number of attacks for each year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Total Number of attacks every year and the trend in which they increase or decrease.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, They would help in determining the trend of total attacks in coming years.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Analysis of number of Attacks per Region
sns.countplot(y='region', data=df)
plt.ylabel('Region')
plt.xlabel('Count')
plt.title('Number of Terrorist Attack by Region')
# Out:
# Text(0.5, 1.0, 'Number of Terrorist Attack by Region')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This specific charts helps in determining total number of times a specific region was attacked.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insight found was - (1) - Region attacked the most number of times and least.
#                     (2) - Danger level of the regions

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, In determining the right region for business and level of security measures.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#Analysis of number of Attacks per Attack Method
f = plt.figure(figsize=(20, 8))
sns.set(font_scale=0.7)
sns.countplot(x='attacktype', data=df,)
plt.xlabel('Methods of Attack')
plt.ylabel('Counts')
plt.title('Types of Terrorist Attack ')
# Out:
# Text(0.5, 1.0, 'Types of Terrorist Attack ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the count of how many times was an specific attack type used.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The amount of type a specific attack type was used over the years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, to understand the attack method and its use frequency so that correct security measures can be employed.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Top 10 most attacked countries by percentage
country_counts = df['country'].value_counts().head(10)
plt.figure(figsize=(10, 10))
sns.set(font_scale=1.2)
sns.set_palette('pastel')
country_counts.plot.pie(autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Terrorist Attacks by Country')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the percentages of whole.( Most attacked countries)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most Attacked and Dangerous countries in the world.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# To avoid those countries which are more susceptible to Terrorism or To take proper security measures before doing business in those countries.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
f = plt.figure(figsize=(20, 8))

sns.set(font_scale=0.8)
xaxis = sns.countplot(x='targettype', data=df,)

xaxis.set_xticklabels(xaxis.get_xticklabels(), rotation=60)
plt.xlabel('Target Types', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Types of Target', fontsize=12)
# Out:
# <ipython-input-20-5e85438152d6>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   xaxis.set_xticklabels(xaxis.get_xticklabels(), rotation=60)
# Text(0.5, 1.0, 'Types of Target')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the count and compare the targets of terrorism

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most targetted sights by terrorist.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help determine the correct security protocols for these targets to avoid future terror attacks.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
df['total_casualties'] = df['nkilled'] + df['nwounded']
plt.figure(figsize=(10,6))
sns.histplot(df['total_casualties'], bins=30, kde=True)
plt.title('Distribution of Total Casualties in Terrorist Attacks')
plt.xlabel('Total Casualties')
plt.ylabel('Frequency')
plt.xlim(0, 200)  # Limiting for better visualization
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with a kernel density estimate (kde) is a suitable choice for visualizing the distribution of total casualties in terrorist attacks. This type of chart provides a clear representation of the frequency distribution of the variable of interest (total casualties) and allows viewers to observe patterns and trends in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By examining the histogram, one can gain insights into the distribution of total casualties in terrorist attacks. The peaks and patterns in the histogram can indicate the frequency of occurrences within specific ranges of total casualties.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can be valuable for various stakeholders, including security agencies, policymakers, and organizations involved in risk management.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(12,7))
sns.countplot(y='weapontype', data=df, order=df['weapontype'].value_counts().index)
plt.title('Weapon Types Used in Terrorist Attacks')
plt.xlabel('Number of Attacks')
plt.ylabel('Weapon Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The choice of a horizontal bar chart (countplot) is suitable for visualizing the frequency of different weapon types used in terrorist attacks. This chart type is effective for comparing the number of occurrences across categories (weapon types) and is especially useful when dealing with categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart provides a clear view of the distribution of terrorist attacks based on weapon types. Each bar represents a specific weapon type, and the length of the bar corresponds to the number of attacks involving that particular weapon.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Businesses operating in regions prone to specific types of attacks can tailor their security measures accordingly.
# Security agencies can allocate resources and intelligence efforts more effectively by understanding the prevalent weapon types.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
kidnapping_df = df[df['victimkidnapped'] == 1]
plt.figure(figsize=(15,6))
sns.countplot(x='year', data=kidnapping_df)
plt.xticks(rotation=90)
plt.title('Kidnapping Incidents Over Years')
plt.ylabel('Number of Kidnappings')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The selected chart is a vertical bar chart (countplot) which is appropriate for visualizing the number of kidnapping incidents over multiple years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides a visual representation of the distribution of kidnapping incidents over the years.
# Peaks or trends in the bar heights can indicate periods of increased or decreased kidnapping activity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights from this chart can be valuable for businesses, security agencies, and organizations involved in risk management:
# Businesses operating in regions with a history of kidnapping incidents can adjust their security protocols and employee training accordingly.
# Security agencies can allocate resources based on the temporal patterns of kidnapping incidents, focusing efforts during periods of higher risk.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
claimed_attacks = df[df['claimedresp'] == 1]
plt.figure(figsize=(12,7))
sns.countplot(y='organisation', data=claimed_attacks, order=claimed_attacks['organisation'].value_counts().iloc[:10].index)
plt.title('Top 10 Organizations by Number of Claimed Attacks')
plt.xlabel('Number of Attacks')
plt.ylabel('Organisation')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a horizontal bar chart (countplot) that effectively displays the top 10 organizations based on the number of claimed attacks. This chart type is suitable for comparing the frequency of claimed attacks among different organizations, providing a clear visual representation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart allows viewers to quickly identify the top 10 organizations responsible for claimed attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Decision-makers can gain insights into the organizations that frequently claim responsibility, potentially leading to a better understanding of the motives and dynamics of these groups.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(12,7))
sns.countplot(y='propdamageextent', data=df, order=df['propdamageextent'].value_counts().index)
plt.title('Extent of Property Damage in Terrorist Attacks')
plt.xlabel('Number of Incidents')
plt.ylabel('Damage Extent')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The selected chart is a horizontal bar chart (countplot) that effectively displays the extent of property damage in terrorist attacks. This chart type is suitable for comparing the frequency of different levels of property damage, providing a clear visual representation of the distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart allows viewers to quickly grasp the distribution of property damage across different extents, ranging from minimal to severe

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1-Businesses can assess the potential impact of terrorist attacks on their properties and infrastructure, adjusting risk management strategies accordingly.
# 2-Property owners can take preventive measures or invest in security measures based on the likelihood of different extents of damage.
# 3-Insurance companies can use this information to refine their risk assessment models and adjust premium rates.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(15,6))
df.groupby('year')['nkilled'].sum().plot(kind='line', color='red', marker='o')
plt.title('Yearly Fatalities Due to Terrorism')
plt.xlabel('Year')
plt.ylabel('Number of Fatalities')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a line plot, which is effective for illustrating trends over time. This type of chart is suitable for visualizing the yearly sum of fatalities due to terrorism. The use of markers enhances visibility and emphasizes individual data points.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1-The line plot provides a clear depiction of the trend in yearly fatalities due to terrorism over the specified period.
# 2-Viewers can easily identify whether the number of fatalities is increasing, decreasing, or experiencing fluctuations over the years.
# 3-Peaks or troughs in the line can highlight specific years with exceptionally high or low numbers of fatalities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Businesses operating in regions with a history of high fatalities can enhance security measures and emergency response protocols

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(12,7))
sns.boxplot(x='nkilled', y='attacktype', data=df)
plt.title('Distribution of Fatalities by Attack Type')
plt.xlabel('Number of Fatalities')
plt.ylabel('Attack Type')
plt.xlim(0, 50)  # Limiting x-axis for better readability
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a boxplot, which is effective for visualizing the distribution of fatalities by attack type. This chart type provides key statistical information, such as the median, quartiles, and potential outliers, allowing for a comprehensive understanding of the data distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Key statistics such as the median and quartiles provide insights into the central tendency and spread of fatalities within each attack type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# understanding the distribution of fatalities by attack type helps in tailoring security measures to address specific risks, contributing to a safer and more secure environment.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(10,7))
plt.hexbin(df['nkilled'], df['nwounded'], gridsize=50, cmap='Reds', mincnt=1)
plt.colorbar(label='Number of Attacks')
plt.title('Density of Terrorist Attacks by Fatalities and Injuries')
plt.xlabel('Number of Fatalities')
plt.ylabel('Number of Injuries')
plt.xlim(0, 100)  # Limit this to focus on the more common outcomes
plt.ylim(0, 100)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a hexbin plot, which is effective for visualizing the density of points in a two-dimensional space. This type of chart is suitable for displaying the relationship between two numerical variables (number of fatalities and number of injuries) and provides a clear indication of the density of terrorist attacks across different levels of fatalities and injuries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The hexbin plot allows viewers to observe the concentration of terrorist attacks in terms of both fatalities and injuries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Emergency response teams can use this information to better prepare for and respond to incidents with varying levels of casualties.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(20,20))
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# <ipython-input-29-f1aeb6655cc9>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a heatmap displaying the correlation matrix of the variables in the dataframe. Heatmaps are effective for visualizing relationships between multiple variables, especially in correlation matrices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap allows viewers to observe the pairwise correlations between different variables in the dataset.
# Positive correlations (closer to 1) are represented by warmer colors, while negative correlations (closer to -1) are represented by cooler colors.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
numerical_cols = ['nkilled', 'victimkidnapped', 'ransomdemanded']
df_numerical = df[numerical_cols]
sns.pairplot(df_numerical)
plt.suptitle('Pairplot of Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The selected chart is a pairplot, which is suitable for visualizing the relationships between multiple numerical variables in a dataset. This type of chart displays scatterplots for each pair of variables and histograms along the diagonal, allowing for a comprehensive view of the data distribution and potential correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Scatterplots help identify patterns and potential correlations between pairs of variables. For example, it can reveal how the number of killings correlates with incidents of kidnapping and instances where ransom is demanded.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
#  Data Integration: Ensure comprehensive integration of terrorism data with internal business data (e.g., operational, supply chain, and employee data) for a holistic risk assessment.
#
# Continuous Monitoring: Implement a robust monitoring system to continuously track and analyze terrorism data, enabling timely identification of emerging threats and proactive risk management.
#
# Investment in Security Measures: Allocate resources towards implementing security measures such as surveillance systems, access controls, and employee training to enhance resilience against potential terrorist threats.
#
# Scenario Planning: Develop scenario-based contingency plans considering various terrorism-related scenarios to minimize disruption to business operations and ensure continuity.
#
# Regular Reviews: Conduct periodic reviews and updates of risk assessments and mitigation strategies in response to evolving terrorism trends and changes in the business environment.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, leveraging comprehensive analysis of terrorism data enables businesses to proactively assess risks, implement effective security measures, and safeguard operations, thereby fostering resilience and ensuring continued success in dynamic operating environments.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
